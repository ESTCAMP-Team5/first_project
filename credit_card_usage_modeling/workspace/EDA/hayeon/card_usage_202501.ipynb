# %% [markdown]
# 가설 1: 시기(시간, 요일, 월)에 따른 소비량 분석

# %%
import pandas as pd
import glob

# %%
path = "C:/Users/USER/Downloads/카드소비 데이터_202501"
all_files = glob.glob(path + "/*.csv")

# %%
df_list = [pd.read_csv(f) for f in all_files]
df = pd.concat(df_list, ignore_index=True)

# %%
df = df.drop(columns=['admi_cty_no', 'card_tpbuz_cd'])

# %%
df.to_csv("2501_gyeonggi_card.csv", index=False)

# %%
path = "C:/Users/USER/Downloads/카드소비 데이터_202502"
all_files = glob.glob(path + "/*.csv")

# %%
df_list = [pd.read_csv(f) for f in all_files]
df = pd.concat(df_list, ignore_index=True)

# %%
df = df.drop(columns=['admi_cty_no', 'card_tpbuz_cd'])

# %%
df.to_csv("2502_gyeonggi_card.csv", index=False)

# %%
path = "C:/Users/USER/Downloads/카드소비 데이터_202503"
all_files = glob.glob(path + "/*.csv")

# %%
df_list = [pd.read_csv(f) for f in all_files]
df = pd.concat(df_list, ignore_index=True)

# %%
df = df.drop(columns=['admi_cty_no', 'card_tpbuz_cd'])

# %%
df.to_csv("2503_gyeonggi_card.csv", index=False)

# %%
path = "C:/ex/1st pjt/credit_card_usage_modeling/workspace/EDA/hayeon"
all_files = glob.glob(path + "/*.csv")

# %%
df_list = [pd.read_csv(f) for f in all_files]
df = pd.concat(df_list, ignore_index=True)

# %%
df.to_csv("2025_gyeonggi_card.csv", index=False)

# %%
df=pd.read_csv("C:/ex/1st pjt/credit_card_usage_modeling/workspace/EDA/hayeon/data/2025_gyeonggi_card.csv")

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False

# %%
df['ta_ymd'] = pd.to_datetime(df['ta_ymd'], format="%Y%m%d")
df['year'] = df['ta_ymd'].dt.year
df['month'] = df['ta_ymd'].dt.month
df['dayofweek'] = df['ta_ymd'].dt.dayofweek  # 0=월 ~ 6=일

# %%
fig, axes = plt.subplots(1, 3, figsize=(18, 4))

sns.barplot(x='hour', y='amt', data=df, estimator='sum', ci=None, ax=axes[0])
axes[0].set_title("시간대별 총 소비금액")

sns.barplot(x='dayofweek', y='amt', data=df, estimator='sum', ci=None, ax=axes[1])
axes[1].set_title("요일별 총 소비금액")
axes[1].set_xticklabels(['월', '화', '수', '목', '금', '토', '일'])

sns.barplot(x='month', y='amt', data=df, estimator='sum', ci=None, ax=axes[2])
axes[2].set_title("월별 총 소비금액")

plt.tight_layout()
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_6820\2556354156.py:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='hour', y='amt', data=df, estimator='sum', ci=None, ax=axes[0])
# C:\Users\USER\AppData\Local\Temp\ipykernel_6820\2556354156.py:6: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='dayofweek', y='amt', data=df, estimator='sum', ci=None, ax=axes[1])
# C:\Users\USER\AppData\Local\Temp\ipykernel_6820\2556354156.py:8: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[1].set_xticklabels(['월', '화', '수', '목', '금', '토', '일'])
# C:\Users\USER\AppData\Local\Temp\ipykernel_6820\2556354156.py:10: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False
sns.set_theme(style="whitegrid", palette="Set2")

# %%
df['ta_ymd'] = pd.to_datetime(df['ta_ymd'], format="%Y%m%d")
df['month'] = df['ta_ymd'].dt.month
df['dayofweek'] = df['ta_ymd'].dt.dayofweek

# %%
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False
plt.figure(figsize=(7, 5))
sns.barplot(x='hour', y='amt', data=df, estimator=np.sum, ci=None)
plt.title("시간대별 총 소비금액", fontsize=14)
plt.xlabel("시간대", fontsize=12)
plt.ylabel("총 소비금액", fontsize=12)
plt.tight_layout()
plt.savefig("시간대별_소비금액_개선.png")
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_6820\2119710857.py:4: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='hour', y='amt', data=df, estimator=np.sum, ci=None)

# %%
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False
sns.set_theme(style="whitegrid", palette="Set2")

# %%
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'Malgun Gothic'  # 윈도우 기본 한글 폰트
plt.rcParams['axes.unicode_minus'] = False     # 마이너스 부호 깨짐 방지

# %%
plt.figure(figsize=(7, 5))
sns.barplot(x='dayofweek', y='amt', data=df, estimator=np.sum, ci=None)
plt.title("요일별 총 소비금액", fontsize=14)
plt.xlabel("요일", fontsize=12)
plt.ylabel("총 소비금액", fontsize=12)
plt.xticks(ticks=range(7), labels=['월', '화', '수', '목', '금', '토', '일'])
plt.tight_layout()
plt.savefig("요일별_소비금액_개선.png")
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_6820\1629674133.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='dayofweek', y='amt', data=df, estimator=np.sum, ci=None)

# %%
plt.figure(figsize=(7, 5))
sns.barplot(x='month', y='amt', data=df, estimator=np.sum, ci=None)
plt.title("월별 총 소비금액", fontsize=14)
plt.xlabel("월", fontsize=12)
plt.ylabel("총 소비금액", fontsize=12)
plt.tight_layout()
plt.savefig("월별_소비금액_개선.png")
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_6820\3377232633.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='month', y='amt', data=df, estimator=np.sum, ci=None)

# %%
region_name_map = {
    '41110': '수원시',
    '41460': '용인시',
    '41590': '화성시',
    '41270': '안산시'
}

# %%
df['region_name'] = df['cty_rgn_no'].map(region_name_map)

# %%
st.subheader("🏷️ 업종 대분류별 소비금액")
buz_df = hour_df.groupby('card_tpbuz_nm_1')['amt'].sum().sort_values(ascending=False).head(5)

fig2, ax2 = plt.subplots()
buz_df.plot(kind='bar', ax=ax2, color='skyblue')
ax2.set_ylabel("총 소비금액")
st.pyplot(fig2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[84], line 1
# ----> 1 st.subheader("🏷️ 업종 대분류별 소비금액")
#       2 buz_df = hour_df.groupby('card_tpbuz_nm_1')['amt'].sum().sort_values(ascending=False).head(5)
#       4 fig2, ax2 = plt.subplots()
#
# NameError: name 'st' is not defined

# %%
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'Malgun Gothic'  # 윈도우 기본 한글 폰트
plt.rcParams['axes.unicode_minus'] = False     # 마이너스 부호 깨짐 방지

# %% [markdown]
# 가설 2: 지역별 소비가 집중된 업종

# %%
region_buz = df.groupby(['cty_rgn_no', 'card_tpbuz_nm_1'])['amt'].sum().reset_index()
top_buz_by_region = region_buz.sort_values(['cty_rgn_no', 'amt'], ascending=[True, False]).groupby('cty_rgn_no').head(1)

print("\n[지역별 소비가 가장 높은 업종]")
print(top_buz_by_region)
# Out:
# [지역별 소비가 가장 높은 업종]
#      cty_rgn_no card_tpbuz_nm_1            amt
# 4         41111           소매/유통   163991259367
# 13        41113           소매/유통   360448614657
# 24        41115              음식   199798016689
# 31        41117           소매/유통   233805448433
# 40        41171           소매/유통   134745078562
# 49        41173           소매/유통   341040933593
# 58        41210           소매/유통   487837439357
# 67        41271           소매/유통   176316245591
# 76        41273           소매/유통   374219279547
# 85        41290           소매/유통    47926102208
# 94        41390           소매/유통   439075411693
# 103       41450           소매/유통   376681165670
# 112       41461           소매/유통   276942251432
# 121       41463           소매/유통   453114649303
# 130       41465           소매/유통   325578106663
# 139       41500           소매/유통   265973041143
# 148       41590           소매/유통  1063512263942
# 157       41650           소매/유통   144422405070

# %% [markdown]
# 가설 3: 소비량이 증가하는 지역/업종

# %%
monthly_trend = df.groupby(['month', 'cty_rgn_no', 'card_tpbuz_nm_1'])['amt'].sum().reset_index()
monthly_pivot = monthly_trend.pivot_table(index=['cty_rgn_no', 'card_tpbuz_nm_1'], columns='month', values='amt').fillna(0)
monthly_pivot['증가율'] = (monthly_pivot[3] - monthly_pivot[1]) / monthly_pivot[1].replace(0, 1)

# %%
print("\n[소비 증가율 상위 지역/업종]")
print(monthly_pivot.sort_values('증가율', ascending=False).head(10))
# Out:
# [소비 증가율 상위 지역/업종]
# month                                  1             2             3       증가율
# cty_rgn_no card_tpbuz_nm_1
# 41210      미디어/통신           9.620838e+09  8.206085e+10  8.807576e+10  8.154687
# 41650      여가/오락            2.327065e+09  2.470097e+09  6.649890e+09  1.857629
# 41461      여가/오락            9.225127e+09  1.078894e+10  2.079842e+10  1.254541
# 41650      공공/기업/단체         1.462576e+09  1.381592e+09  2.928195e+09  1.002080
# 41461      공연/전시            1.512342e+08  1.148062e+08  2.589290e+08  0.712106
# 41113      공공/기업/단체         9.536831e+08  1.240183e+09  1.591900e+09  0.669212
# 41463      여가/오락            6.347293e+09  6.445369e+09  1.026667e+10  0.617489
# 41210      음식               3.840939e+10  5.080230e+10  5.969135e+10  0.554082
# 41500      공공/기업/단체         6.789971e+08  6.852997e+08  1.035666e+09  0.525288
# 41117      공연/전시            5.481478e+07  5.108978e+07  7.997157e+07  0.458942

# %% [markdown]
# 가설 4: 소비 급증 시기 → 외부 요인 탐지 (시각화용)

# %%
daily_amt = df.groupby('ta_ymd')['amt'].sum()
daily_amt.plot(title="일별 소비 추이 (이상치 확인용)", figsize=(12, 4))
plt.ylabel("총 소비 금액")
plt.xlabel("날짜")
plt.grid()
plt.show()

# %% [markdown]
# 가설 5: 고소비 vs 저소비 지역 비교

# %%
region_total = df.groupby('region_name')['amt'].sum().sort_values(ascending=False)
top_regions = region_total.head(2).index
bottom_regions = region_total.tail(2).index
